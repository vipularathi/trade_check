# %%
import pandas as pd
import re
import os
from datetime import datetime
import warnings

warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)
pd.set_option('display.max_columns', None)

# %%
# today = datetime.now().date().strftime('%Y%m%d')
today = pd.to_datetime('20241107')
drop_pattern = rf'dropcopy_positions_{today.strftime("%Y%m%d")}_\d{{6}}\.xlsx' # sample = dropcopy_positions_20241107_165710
our_pattern = rf'Output_{today.strftime("%d-%b-%y")} \d{{2}}-\d{{2}}-\d{{2}}\.xlsx' # sample = Output_07-Nov-24 15-34-07.xlsx

# %%
root_dir = os.getcwd()
our_file_path = os.path.join(root_dir, 'Our_file')
their_file_path = os.path.join(root_dir, 'Their_file')

# %%
matched_files = [f for f in os.listdir(their_file_path) if re.match(drop_pattern, f)]
df_drop = pd.DataFrame()
for each_file in matched_files:
    temp_df = pd.read_excel(os.path.join(their_file_path, each_file), index_col=False)
    df_drop = pd.concat([df_drop, temp_df])
# df_drop = pd.read_excel(r'D:\trade_file_analysis\dropcopy_positions_20241105_201400.xlsx', index_col=False)

matched_files = [f for f in os.listdir(our_file_path) if re.match(our_pattern, f)]
df_output = pd.DataFrame()
for each_file in matched_files:
    temp_df = pd.read_excel(os.path.join(our_file_path, each_file), index_col=False)
    df_output = pd.concat([df_output, temp_df])
# df_output = pd.read_excel(r'D:\trade_file_analysis\Output_06-Nov-24 15-43-26.xlsx', index_col=False)

df_drop = df_drop.iloc[:, 1:]
df_output = df_output[~df_output['Source1'].str.startswith('Nest')]
df_output.rename(columns = {'Instrument Name' : 'Instrument_Name', 'Option Type': 'Option_Type', 'Series/Expiry' : 'Expiry'}, inplace=True)
def convert_to_timestamp(date_str):
    # Remove suffixes from the day part
    date_str = date_str.replace('st', '').replace('nd', '').replace('rd', '').replace('th', '')

    # Parse the date with pandas, specifying the format
    try:
        return pd.to_datetime(date_str, format='%Y%B%d')
    except ValueError:
        return pd.NaT  # Return NaT if parsing fails

df_drop['Expiry'] = df_drop['Expiry'].apply(convert_to_timestamp)

# %%
grouped_df = df_output.groupby(['Symbol', 'Expiry', 'Option_Type'])['Strike'].unique().reset_index()
for index, row in grouped_df.iterrows():
    print(index)
    # print(type(row))
    symbol = row['Symbol']
    expiry = row['Expiry']
    opttype = row['Option_Type']
    for each_strike in row['Strike']:
        print(symbol, expiry, opttype, each_strike)
        temp_op_df = df_output.query("Symbol == @symbol and Expiry == @expiry and Option_Type == @opttype and Strike == @each_strike")
        temp_drop_df = df_drop.query("Symbol == @symbol and Expiry == @expiry and InstType == @opttype and StrikePrice == @each_strike")
        # print(temp_op_df)

        op_buy_qty = sum(temp_op_df['BuyQty'])
        drop_buy_qty = sum(temp_drop_df['BuyQty'])
        temp_op_df.loc[:, 'buy_value'] = temp_op_df['BuyQty'] * temp_op_df['BuyPrice']
        op_buy_value = temp_op_df['buy_value'].sum()

        op_sell_qty = sum(temp_op_df['SellQty'])
        drop_sell_qty = sum(temp_drop_df['SellQty'])
        temp_op_df.loc[:, 'sell_value'] = temp_op_df['SellQty'] * temp_op_df['SellPrice']
        op_sell_value = temp_op_df['sell_value'].sum()

        if op_buy_qty == drop_buy_qty:
            if op_buy_value == temp_drop_df['BuyValue'].sum():
                continue
            else:
                print(f'Buy Value Mismatch: {symbol}, {expiry}, {opttype}, {each_strike}')
                flag = False
        else:
            print(f'Buy Quantity Mismatch: {symbol}, {expiry}, {opttype}, {each_strike}')
            flag = False

        if op_sell_qty == drop_sell_qty:
            if op_sell_value == temp_drop_df['SellValue'].sum():
                continue
            else:
                print(f'Sell Value Mismatch: {symbol}, {expiry}, {opttype}, {each_strike}')
                flag = False
        else:
            print(f'Sell Quantity Mismatch: {symbol}, {expiry}, {opttype}, {each_strike}')
            flag = False
if flag:
    print('No mismatch between the dropcopy and inhouse consolidated trade file')
# Out:
# 0
# BANKNIFTY 2024-11-13 00:00:00 CE 52500
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52500
# BANKNIFTY 2024-11-13 00:00:00 CE 51900
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 51900
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 51900
# BANKNIFTY 2024-11-13 00:00:00 CE 52600
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52600
# BANKNIFTY 2024-11-13 00:00:00 CE 52800
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52800
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52800
# BANKNIFTY 2024-11-13 00:00:00 CE 52200
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52200
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52200
# BANKNIFTY 2024-11-13 00:00:00 CE 52100
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52100
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52100
# BANKNIFTY 2024-11-13 00:00:00 CE 53100
# BANKNIFTY 2024-11-13 00:00:00 CE 53300
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 53300
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 53300
# BANKNIFTY 2024-11-13 00:00:00 CE 52300
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52300
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52300
# BANKNIFTY 2024-11-13 00:00:00 CE 52000
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52000
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52000
# BANKNIFTY 2024-11-13 00:00:00 CE 52400
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52400
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52400
# BANKNIFTY 2024-11-13 00:00:00 CE 52700
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52700
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 52700
# BANKNIFTY 2024-11-13 00:00:00 CE 54000
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 54000
# BANKNIFTY 2024-11-13 00:00:00 CE 53000
# BANKNIFTY 2024-11-13 00:00:00 CE 52900
# BANKNIFTY 2024-11-13 00:00:00 CE 53200
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 53200
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, CE, 53200
# 1
# BANKNIFTY 2024-11-13 00:00:00 PE 51000
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 51000
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 51000
# BANKNIFTY 2024-11-13 00:00:00 PE 52500
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52500
# BANKNIFTY 2024-11-13 00:00:00 PE 51900
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 51900
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 51900
# BANKNIFTY 2024-11-13 00:00:00 PE 52200
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52200
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52200
# BANKNIFTY 2024-11-13 00:00:00 PE 51500
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 51500
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 51500
# BANKNIFTY 2024-11-13 00:00:00 PE 52100
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52100
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52100
# BANKNIFTY 2024-11-13 00:00:00 PE 52300
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52300
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52300
# BANKNIFTY 2024-11-13 00:00:00 PE 52000
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52000
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52000
# BANKNIFTY 2024-11-13 00:00:00 PE 50900
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 50900
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 50900
# BANKNIFTY 2024-11-13 00:00:00 PE 49500
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 49500
# BANKNIFTY 2024-11-13 00:00:00 PE 52400
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52400
# Sell Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52400
# BANKNIFTY 2024-11-13 00:00:00 PE 52600
# Buy Value Mismatch: BANKNIFTY, 2024-11-13 00:00:00, PE, 52600
# 2
# FINNIFTY 2024-11-12 00:00:00 CE 23950
# Buy Value Mismatch: FINNIFTY, 2024-11-12 00:00:00, CE, 23950
# Sell Value Mismatch: FINNIFTY, 2024-11-12 00:00:00, CE, 23950
# FINNIFTY 2024-11-12 00:00:00 CE 24000
# Buy Value Mismatch: FINNIFTY, 2024-11-12 00:00:00, CE, 24000
# Sell Value Mismatch: FINNIFTY, 2024-11-12 00:00:00, CE, 24000
# FINNIFTY 2024-11-12 00:00:00 CE 24150
# Buy Value Mismatch: FINNIFTY, 2024-11-12 00:00:00, CE, 24150
# Sell Value Mismatch: FINNIFTY, 2024-11-12 00:00:00, CE, 24150
# FINNIFTY 2024-11-12 00:00:00 CE 24250
# Buy Value Mismatch: FINNIFTY, 2024-11-12 00:00:00, CE, 24250
# FINNIFTY 2024-11-12 00:00:00 CE 24050
# Buy Value Mismatch: FINNIFTY, 2024-11-12 00:00:00
# Buy Value Mismatch: NIFTY, 2024-11-07 00:00:00, PE, 24200
# Sell Value Mismatch: NIFTY, 2024-11-07 00:00:00, PE, 24200
# NIFTY 2024-11-07 00:00:00 PE 24450
# Buy Value Mismatch: NIFTY, 2024-11-07 00:00:00, PE, 24450
# Sell Value Mismatch: NIFTY, 2024-11-07 00:00:00, PE, 24450
# NIFTY 2024-11-07 00:00:00 PE 24250
# Buy Value Mismatch: NIFTY, 2024-11-07 00:00:00, PE, 24250
# NIFTY 2024-11-07 00:00:00 PE 24400
# NIFTY 2024-11-07 00:00:00 PE 24350
# Buy Value Mismatch: NIFTY, 2024-11-07 00:00:00, PE, 24350
# Sell Value Mismatch: NIFTY, 2024-11-07 00:00:00, PE, 24350
# 8
# NIFTY 2024-11-14 00:00:00 CE 24200
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24200
# Sell Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24200
# NIFTY 2024-11-14 00:00:00 CE 24150
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24150
# Sell Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24150
# NIFTY 2024-11-14 00:00:00 CE 24300
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24300
# Sell Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24300
# NIFTY 2024-11-14 00:00:00 CE 24600
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24600
# NIFTY 2024-11-14 00:00:00 CE 24550
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24550
# NIFTY 2024-11-14 00:00:00 CE 24500
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24500
# Sell Value Mismatch: NIFTY, 2024-11-14 00:00:00, CE, 24500
# NIFTY 2024-11-14 00:00:00 CE 24400
# NIFTY 2024-11-14 00:00:00 CE 24350
# 9
# NIFTY 2024-11-14 00:00:00 PE 24600
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24600
# NIFTY 2024-11-14 00:00:00 PE 24200
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24200
# Sell Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24200
# NIFTY 2024-11-14 00:00:00 PE 23200
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 23200
# NIFTY 2024-11-14 00:00:00 PE 23500
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 23500
# NIFTY 2024-11-14 00:00:00 PE 24150
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24150
# Sell Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24150
# NIFTY 2024-11-14 00:00:00 PE 24300
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24300
# Sell Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24300
# NIFTY 2024-11-14 00:00:00 PE 24500
# NIFTY 2024-11-14 00:00:00 PE 24400
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24400
# Sell Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24400
# NIFTY 2024-11-14 00:00:00 PE 24350
# NIFTY 2024-11-14 00:00:00 PE 24550
# Buy Value Mismatch: NIFTY, 2024-11-14 00:00:00, PE, 24550
# 10
# NIFTY 2025-01-30 00:00:00 PE 23000
